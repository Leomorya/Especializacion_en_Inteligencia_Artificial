# %% [markdown]
# # Taller #0 Archivos notebooks
# ### Presentado por: Leonardo Sánchez
# ### Presentado a: Felipe Palta
# ## Universidad Autónoma de Occidente
# ## Especialización en Inteligencia Artificial

# %%
print("Mi primer tarea")
# Out:
# Mi primer tarea

# %% [markdown]
# ## Mi primera imagen
# **La inteligencia artificial es genial**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La imagen anterior fue tomada de [¿Qué es la inteligencia artificial?](https://elordenmundial.com/que-es-inteligencia-artificial/).

# %%
a=1
b=2
print(f"La suma es:\n{a+b}")
# Out:
# La suma es:
# 3
